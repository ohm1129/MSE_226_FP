# %% [markdown]
# # Baseline Models for Online Shoppers Purchase Prediction
#
# This notebook implements and evaluates two baseline models:
# 1. **Baseline 1**: Majority Class Classifier (always predict "No Purchase")
# 2. **Baseline 2**: Logistic Regression with all features (no tuning)
#
# ## Evaluation Metrics
# - **F1-Score** (primary): Balances precision and recall
# - **ROC-AUC**: Measures discriminative ability
# - **Precision**: How many predicted purchases are correct
# - **Recall**: How many actual purchases we catch
# - **Accuracy**: Overall correctness (less meaningful with class imbalance)

# %% [markdown]
# ## 1. Setup and Data Loading

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, classification_report, confusion_matrix
)
from sklearn.dummy import DummyClassifier
import warnings
warnings.filterwarnings('ignore')

# Import the evaluate_model function
from evaluate_model import evaluate_model

# Set random seed for reproducibility
np.random.seed(42)

# %%
# Load preprocessed training data
print("Loading preprocessed training data...")
train_df = pd.read_csv('../data/train_data_preprocessed.csv')

# Prepare features and target (data is already preprocessed)
X = train_df.drop('Revenue', axis=1)
Y = train_df['Revenue']

print(f"\nFeatures shape: {X.shape}")
print(f"Features: {list(X.columns)}")
# Out:
# Loading preprocessed training data...
#
# Features shape: (9864, 17)
# Features: ['Administrative', 'Administrative_Duration', 'Informational', 'Informational_Duration', 'ProductRelated', 'ProductRelated_Duration', 'BounceRates', 'ExitRates', 'PageValues', 'SpecialDay', 'Month', 'OperatingSystems', 'Browser', 'Region', 'TrafficType', 'VisitorType', 'Weekend']

# %%
# Setup cross-validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
baseline1 = DummyClassifier(strategy='most_frequent', random_state=42)
results_baseline1 = evaluate_model(baseline1, X, Y, cv, "Baseline 1: Majority Class Classifier")
# Out:
# ============================================================
# Evaluating Baseline 1: Majority Class Classifier
# ============================================================
#
# 5-Fold Cross-Validation Results:
#   Accuracy:  0.8453 (+/- 0.0002)
#   F1-Score:  0.0000 (+/- 0.0000)
#   Precision: 0.0000 (+/- 0.0000)
#   Recall:    0.0000 (+/- 0.0000)
#   ROC-AUC:   0.5000 (+/- 0.0000)
#
# Full Training Set Performance:
#   Accuracy:  0.8453
#   F1-Score:  0.0000
#   Precision: 0.0000
#   Recall:    0.0000
#   ROC-AUC:   0.5000
#
# Confusion Matrix:
#   TN:  8338  |  FP:     0
#   FN:  1526  |  TP:     0

# %% [markdown]
# baseline1 = DummyClassifier(strategy='most_frequent', random_state=42)
# results_baseline1 = evaluate_model(baseline1, X, y, cv, "Baseline 1: Majority Class Classifier")

# %%
baseline2 = LogisticRegression(random_state=42, max_iter=1000)
results_baseline2 = evaluate_model(baseline2, X, Y, cv, "Baseline 2: Logistic Regression (No Tuning)")
# Out:
# ============================================================
# Evaluating Baseline 2: Logistic Regression (No Tuning)
# ============================================================
#
# 5-Fold Cross-Validation Results:
#   Accuracy:  0.8810 (+/- 0.0058)
#   F1-Score:  0.4869 (+/- 0.0360)
#   Precision: 0.7291 (+/- 0.0276)
#   Recall:    0.3663 (+/- 0.0369)
#   ROC-AUC:   0.8726 (+/- 0.0093)
#
# Full Training Set Performance:
#   Accuracy:  0.8809
#   F1-Score:  0.4844
#   Precision: 0.7331
#   Recall:    0.3617
#   ROC-AUC:   0.8702
#
# Confusion Matrix:
#   TN:  8137  |  FP:   201
#   FN:   974  |  TP:   552

# %% [markdown]
# ## 4. Baseline 2: Logistic Regression (No Tuning)
#
# Standard logistic regression using all features without hyperparameter tuning.
