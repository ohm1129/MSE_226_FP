# %% [markdown]
# # Baseline Models for Online Shoppers Purchase Prediction
#
# This notebook implements and evaluates two baseline models:
# 1. **Baseline 1**: Majority Class Classifier (always predict "No Purchase")
# 2. **Baseline 2**: Logistic Regression with all features (no tuning)
#
# ## Evaluation Metrics
# - **F1-Score** (primary): Balances precision and recall
# - **ROC-AUC**: Measures discriminative ability
# - **Precision**: How many predicted purchases are correct
# - **Recall**: How many actual purchases we catch
# - **Accuracy**: Overall correctness (less meaningful with class imbalance)

# %% [markdown]
# ## 1. Setup and Data Loading

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, classification_report, confusion_matrix
)
from sklearn.dummy import DummyClassifier
import warnings
warnings.filterwarnings('ignore')

# Import the evaluate_model function (works from repo root or models/)
import os, sys
sys.path.append(os.path.abspath('..'))
from models.evaluate_model import evaluate_model

# Set random seed for reproducibility
np.random.seed(42)

# %%
# Load preprocessed training data
print("Loading preprocessed training data...")
train_df = pd.read_csv('../data/train_data_preprocessed.csv')

# Prepare features and target (data is already preprocessed)
X = train_df.drop('y', axis=1)
Y = train_df['y']

print(f"\nFeatures shape: {X.shape}")
print(f"Features: {list(X.columns)}")
# Out:
# Loading preprocessed training data...
#
# Features shape: (36168, 16)
# Features: ['age', 'job', 'marital', 'education', 'default', 'balance', 'housing', 'loan', 'contact', 'day_of_week', 'month', 'duration', 'campaign', 'pdays', 'previous', 'poutcome']

# %%
# One-hot encode categorical features for models that require numeric input
categorical_cols = [col for col in X.columns if X[col].dtype == 'object']
X_processed = pd.get_dummies(X, columns=categorical_cols, drop_first=True)

print(f'Encoded features shape: {X_processed.shape}')

# %%
# Setup cross-validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
baseline1 = DummyClassifier(strategy='most_frequent', random_state=42)
results_baseline1 = evaluate_model(baseline1, X_processed, Y, cv, "Baseline 1: Majority Class Classifier")
# Out:
# ...
# Evaluating Baseline 1: Majority Class Classifier
# ...
#
# 5-Fold Cross-Validation Results:
#   Accuracy:  0.8832 (+/- 0.0001)
#   F1-Score:  nan (+/- nan)
#   Precision: nan (+/- nan)
#   Recall:    nan (+/- nan)
#   ROC-AUC:   0.5000 (+/- 0.0000)
#
# Full Training Set Performance:
#   Accuracy:  0.8832
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 baseline1 = DummyClassifier(strategy='most_frequent', random_state=42)
# ----> 2 results_baseline1 = evaluate_model(baseline1, X, Y, cv, "Baseline 1: Majority Class Classifier")
#
# File ~/Desktop/MSE_226_FP/models/evaluate_model.py:40, in evaluate_model(model, X, y, cv, model_name)
#      38 print(f"\nFull Training Set Performance:")
#      39 print(f"  Accuracy:  {accuracy_score(y, y_pred):.4f}")
# ---> 40 print(f"  F1-Score:  {f1_score(y, y_pred):.4f}")
# ...

# %%
# Logistic Regression (no tuning) on encoded features
baseline2 = LogisticRegression(random_state=42, max_iter=1000, solver='liblinear')
results_baseline2 = evaluate_model(baseline2, X_processed, Y, cv, "Baseline 2: Logistic Regression (No Tuning)")
# Out:
# ...
# Evaluating Baseline 2: Logistic Regression (No Tuning)
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 baseline2 = LogisticRegression(random_state=42, max_iter=1000)
# ----> 2 results_baseline2 = evaluate_model(baseline2, X, Y, cv, "Baseline 2: Logistic Regression (No Tuning)")
#
# File ~/Desktop/MSE_226_FP/models/evaluate_model.py:20, in evaluate_model(model, X, y, cv, model_name)
#      17 print(f"{'='*60}")
#      19 # Cross-validation scores
# ---> 20 cv_accuracy = cross_val_score(model, X, y, cv=cv, scoring='accuracy')
#      21 cv_f1 = cross_val_score(model, X, y, cv=cv, scoring='f1')
#      22 cv_precision = cross_val_score(model, X, y, cv=cv, scoring='precision')
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
# ...

# %% [markdown]
# ## 4. Baseline 2: Logistic Regression (No Tuning)
#
# Standard logistic regression using all features without hyperparameter tuning.
